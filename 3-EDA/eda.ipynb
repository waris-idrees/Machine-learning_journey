# %% [markdown]
# # EDA

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the Data set

# %%
df = pd.read_csv("data_set.csv")
df.head()
# Out:
#   customer_id   age  gender        city     income education  \
# 0     C100000  18.0    Male  Faisalabad   97203.41  Bachelor
# 1     C100001  56.0  Female   Islamabad  132084.64    Matric
# 2     C100002  51.0  Female      Lahore   39789.24  Bachelor
# 3     C100003  21.0  Female   Islamabad  110957.74    Matric
# 4     C100004  69.0  Female  Rawalpindi  127385.88    Master
#
#    experience_years  monthly_spending credit_score signup_date  \
# 0                33          34323.67        728.0  2020-01-01
# 1                20          36955.51        439.0  2020-01-02
# 2                26          30520.91        516.0  2020-01-03
# 3                23          34385.96        520.0  2020-01-04
# 4                18          34126.80        715.0  2020-01-05
#
#   has_credit_card  loan_amount employment_type  defaulted
# 0             Yes    162409.81      Unemployed          0
# 1             Yes    207532.68      Government          0
# 2             Yes    261934.54      Government          0
# 3              No          NaN         Student          1
# 4              No     92532.55        Business          0

# %% [markdown]
# # Check Dataset Shape

# %%
df.shape
# Out:
# (3035, 14)

# %% [markdown]
# # Check Column Names

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'city', 'income', 'education',
#        'experience_years', 'monthly_spending', 'credit_score', 'signup_date',
#        'has_credit_card', 'loan_amount', 'employment_type', 'defaulted'],
#       dtype='str')

# %% [markdown]
# # Check Basic Statistics

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       3035 non-null   str
#  1   age               2945 non-null   float64
#  2   gender            3035 non-null   str
#  3   city              2959 non-null   str
#  4   income            2885 non-null   str
#  5   education         2975 non-null   str
#  6   experience_years  3035 non-null   int64
#  7   monthly_spending  2915 non-null   float64
#  8   credit_score      2974 non-null   str
#  9   signup_date       3035 non-null   str
#  10  has_credit_card   3035 non-null   str
#  11  loan_amount       2914 non-null   float64
#  12  employment_type   3035 non-null   str
#  13  defaulted         3035 non-null   int64
# dtypes: float64(3), int64(2), str(9)
# memory usage: 332.1 KB

# %%
df.describe()
# Out:
#                age  experience_years  monthly_spending    loan_amount  \
# count  2945.000000       3035.000000      2.915000e+03    2914.000000
# mean     46.283871         16.775947      3.913752e+04  247984.727550
# std      24.322314         10.144371      1.871725e+05  121466.717049
# min      -5.000000          0.000000     -3.126420e+04 -207501.650000
# 25%      32.000000          8.000000      2.485272e+04  165214.540000
# 50%      46.000000         17.000000      3.482211e+04  244670.305000
# 75%      60.000000         26.000000      4.454477e+04  329232.120000
# max     999.000000         34.000000      9.999999e+06  688174.170000
#
#          defaulted
# count  3035.000000
# mean      0.237891
# std       0.425862
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %% [markdown]
# # Analyze Numerical Features

# %%
num_col= df.select_dtypes(include="number")
num_col
# Out:
#        age  experience_years  monthly_spending  loan_amount  defaulted
# 0     18.0                33          34323.67    162409.81          0
# 1     56.0                20          36955.51    207532.68          0
# 2     51.0                26          30520.91    261934.54          0
# 3     21.0                23          34385.96          NaN          1
# 4     69.0                18          34126.80     92532.55          0
# ...    ...               ...               ...          ...        ...
# 3030  58.0                15          41294.78    373470.82          0
# 3031  42.0                34          24988.27    276642.15          0
# 3032  48.0                 8          38071.27    272737.10          0
# 3033  23.0                32          49512.70    251914.61          0
# 3034  50.0                11          21699.10    335479.01          0
#
# [3035 rows x 5 columns]

# %%
for col in num_col:
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()
    plt.tight_layout()
plt.show()

# %% [markdown]
# # Analyze Categorical Features

# %%
obj_col = df.select_dtypes(include="object")
obj_col
# Out:
# C:\Users\Cyber\AppData\Local\Temp\ipykernel_12272\199116266.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   obj_col = df.select_dtypes(include="object")
#      customer_id  gender        city     income     education credit_score  \
# 0        C100000    Male  Faisalabad   97203.41      Bachelor        728.0
# 1        C100001  Female   Islamabad  132084.64        Matric        439.0
# 2        C100002  Female      Lahore   39789.24      Bachelor        516.0
# 3        C100003  Female   Islamabad  110957.74        Matric        520.0
# 4        C100004  Female  Rawalpindi  127385.88        Master        715.0
# ...          ...     ...         ...        ...           ...          ...
# 3030     C102051    Male  Rawalpindi   36529.58      Bachelor        803.0
# 3031     C100203    Male      Lahore   65506.98  Intermediate        427.0
# 3032     C102772    Male     Karachi  155931.04           PhD          NaN
# 3033     C100852  Female     Karachi   95938.08  Intermediate        663.0
# 3034     C102392    Male  Rawalpindi  113460.49      Bachelor        619.0
#
#      signup_date has_credit_card employment_type
# 0     2020-01-01             Yes      Unemployed
# 1     2020-01-02             Yes      Government
# 2     2020-01-03             Yes      Government
# 3     2020-01-04              No         Student
# 4     2020-01-05              No        Business
# ...          ...             ...             ...
# 3030  2025-08-13             Yes      Unemployed
# 3031  2020-07-22             Yes         Private
# 3032  2027-08-04              No        Business
# 3033  2022-05-02             Yes      Unemployed
# 3034  2026-07-20              No         Student
#
# [3035 rows x 9 columns]

# %%
sns.countplot(data=df , x="gender")
plt.show()

# %%
for col in obj_col:
    sns.countplot(data=df, x=col)
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=45)
    plt.show()
